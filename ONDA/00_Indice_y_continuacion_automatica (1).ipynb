# %% [markdown]
# # Ecuación de onda — ruta corta para el Examen General
#
# Este índice prioriza comprensión, derivación y problemas representativos. Los notebooks con **★** contienen un ejercicio de nivel General; no es necesario repetir un problema General en cada sección.
#
# ## Ruta recomendada
#
# 1. `02_01_Cauchy_global_y_dAlembert (1).ipynb` — fórmula de d’Alembert.
# 2. `02_02_Dependencia_y_rango_de_influencia (1).ipynb` — dominio de dependencia y soporte finito.
# 3. `02_04_Problema_no_homogeneo_y_Duhamel (1).ipynb` — fuerza externa y principio de Duhamel.
# 4. `02_05_Semirrecta_y_metodo_de_reflexion.ipynb` — reflexión impar/par en una semirrecta.
# 5. `02_06_Intervalo_extremos_fijos_y_compatibilidad (1).ipynb` — guía de intervalo finito; estudiar junto con separación de variables.
# 6. `02_08_Metodo_de_energia (1).ipynb` — conservación de energía, unicidad y velocidad finita.
# 7. **★** `02_10_Dimension_dos_y_descenso_de_Hadamard (1).ipynb` — fórmula de Poisson en dos dimensiones y colas.
# 8. `02_11_Duhamel_multidimensional_y_auditoria_final (1).ipynb` — Duhamel en varias dimensiones y lista de control.
#
# ## Qué debe poder hacerse sin apuntes
#
# - Derivar y usar d’Alembert, incluida la región de influencia.
# - Imponer condiciones de Dirichlet o Neumann por reflexión.
# - Obtener modos en un intervalo y verificar compatibilidad en las esquinas.
# - Probar unicidad con el método de energía.
# - Distinguir el principio de Huygens en dimensiones 1, 2 y 3.
#
# Las animaciones están planteadas para mostrar el dato inicial durante al menos 4 s, desarrollar la idea sin superponer rótulos y cerrar con una pausa de al menos 3 s.
