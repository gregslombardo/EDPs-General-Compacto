# %% [markdown]
# # Índice maestro final — Ecuación de onda
#
# | Sección | Contenido | Estado |
# |---|---|---|
# | 2.1 | Cauchy global y d’Alembert | terminada |
# | 2.2 | Dependencia y rango de influencia | terminada |
# | 2.3 | Caracterización y paralelogramo | terminada |
# | 2.4 | Problema no homogéneo y Duhamel 1D | terminada |
# | 2.5 | Semirrecta y reflexión impar | terminada |
# | 2.6 | Intervalo, extremos fijos y compatibilidad | terminada |
# | 2.7 | Series de Fourier y estabilidad | terminada |
# | 2.8 | Método de energía | terminada |
# | 2.9 | Onda en tres dimensiones | terminada |
# | 2.10 | Dimensión dos y descenso de Hadamard | terminada |
# | 2.11 | Duhamel multidimensional y auditoría final | terminada |
#
# El capítulo queda cerrado.
