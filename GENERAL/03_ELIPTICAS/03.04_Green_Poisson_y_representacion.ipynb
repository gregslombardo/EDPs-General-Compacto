# %% [markdown]
# # 03.04 — Función de Green, núcleo de Poisson y representación
#
# **Prioridad para el General:** ALTA
# **Patrón histórico:** Green aparece explícitamente en 2023-2 y 2025-1.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# La función de Green satisface
# \[
# -\Delta_xG(x,y)=\delta_y,\qquad G(\cdot,y)=0\text{ en }\partial\Omega.
# \]
# La segunda identidad de Green conduce a
# \[
# u(x)=\int_\Omega G(x,y)f(y)\,dy
# -\int_{\partial\Omega}g(y)\partial_{\nu_y}G(x,y)\,dS_y.
# \]
# El núcleo de Poisson es \(P(x,y)=-\partial_{\nu_y}G(x,y)\).

# %% [markdown]
# ## Interpretación geométrica o física
#
# Green es la respuesta del dominio a una fuente puntual con la frontera
# fijada. El núcleo de Poisson reparte la influencia de cada punto de la
# frontera sobre el punto interior.

# %% [markdown]
# ## Ejemplo guiado
#
# En el semiespacio, el método de imágenes resta la fuente reflejada para
# anular \(G\) en el plano frontera.

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 03.04.1
#
# Deriva la simetría \(G(x,y)=G(y,x)\) usando la segunda identidad de Green fuera de pequeñas bolas.
#
# ### Ejercicio normal 03.04.2
#
# Obtén el núcleo de Poisson del semiespacio a partir de la solución fundamental y una fuente imagen.

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
