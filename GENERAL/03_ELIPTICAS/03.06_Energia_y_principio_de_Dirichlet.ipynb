# %% [markdown]
# # 03.06 — Energía y principio de Dirichlet
#
# **Prioridad para el General:** MEDIA
# **Patrón histórico:** Es una vía variacional importante y soporte de unicidad, aunque aparece menos como problema aislado.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# Para datos de frontera fijados se minimiza
# \[
# \mathcal E[v]=\frac12\int_\Omega|\nabla v|^2\,dx-\int_\Omega fv\,dx.
# \]
# La primera variación en dirección \(\varphi\in H_0^1(\Omega)\) es
# \[
# \int_\Omega\nabla u\cdot\nabla\varphi-\int_\Omega f\varphi.
# \]
# Su anulación es la formulación débil de \(-\Delta u=f\). La convexidad
# estricta da unicidad.

# %% [markdown]
# ## Interpretación geométrica o física
#
# La solución de Poisson es la configuración de menor energía entre todas
# las superficies con la misma frontera. Las perturbaciones admisibles se
# anulan en el borde.

# %% [markdown]
# ## Ejemplo guiado
#
# Si \(u\) resuelve el problema homogéneo y \(v=u+w\) con
# \(w\in H_0^1\), entonces
# \(\mathcal E[v]=\mathcal E[u]+\frac12\int|\nabla w|^2\).

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 03.06.1
#
# Calcula la primera variación de \(\mathcal E[u+\varepsilon\varphi]\) y recupera la ecuación de Euler-Lagrange.
#
# ### Ejercicio normal 03.06.2
#
# Demuestra unicidad del minimizador usando la identidad del paralelogramo o convexidad estricta.

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
