# %% [markdown]
# # 03.03 — Principios del máximo, comparación, unicidad y estabilidad
#
# **Prioridad para el General:** ALTA
# **Patrón histórico:** Máximo exterior en 2023-1, unicidad de Cauchy en 2025-2 y estimación de Poisson en 2026-1.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# Si \(\Delta u\ge0\), el máximo de \(u\) en un dominio acotado se alcanza
# en la frontera. Aplicar el resultado a \(u-v\) produce comparación y
# unicidad. Para \(-\Delta u=f\), una barrera \(w\) con
# \(-\Delta w\ge|f|\) y control de frontera da una estimación a priori.

# %% [markdown]
# ## Interpretación geométrica o física
#
# Una membrana sin fuentes no puede formar un máximo interior estricto.
# Las fuentes curvan la membrana; las barreras superior e inferior encierran la
# solución.

# %% [markdown]
# ## Visualización
#
# <video controls preload="metadata" style="max-width: 100%; height: auto;">
#   <source src="../../lAPLACE/animaciones/03.3.A_principio_debil_maximo.mp4" type="video/mp4">
# </video>
#
# > Si el reproductor no carga en GitHub, abre el notebook localmente; la ruta es relativa al repositorio.

# %% [markdown]
# ## Ejemplo guiado
#
# En \(B_1\), \(-\Delta(1-|x|^2)=2n\). Por ello múltiplos de
# \(1-|x|^2\) sirven como barreras para fuentes acotadas.

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 03.03.1
#
# Demuestra unicidad del problema de Dirichlet para \(\Delta u=0\) aplicando el máximo a \(u-v\).
#
# ### Ejercicio normal 03.03.2
#
# Si \(-\Delta u=f\) en \(B_1\) y \(u=0\) en la frontera, usa \(1-|x|^2\) para acotar \(\|u\|_\infty\) por \(\|f\|_\infty\).
#
# ### Problema tipo General 03.03.G
#
# Sea \(\Omega\subset B_R\) y
# \(-\Delta u+\lambda u=f\), \(\lambda\ge0\), con \(u=g\) en
# \(\partial\Omega\). Construya barreras explícitas y pruebe una estimación
# \(\|u\|_\infty\le C(R,n,\lambda)\|f\|_\infty+\|g\|_\infty\). Indique dónde
# se usa el signo de \(\lambda\).

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
