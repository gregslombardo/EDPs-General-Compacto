# %% [markdown]
# # 02.02 — Semirrecta, reflexión y compatibilidad
#
# **Prioridad para el General:** MEDIA
# **Patrón histórico:** Es técnica necesaria para los problemas de semieje y frontera.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# En \(x>0\), Dirichlet homogénea se obtiene extendiendo \(f,g\) de manera
# impar; Neumann homogénea, de manera par. Después se aplica d'Alembert en toda
# la recta. En la esquina se requiere compatibilidad: para Dirichlet,
# \(f(0)=0\); para Neumann, \(f'(0)=0\), además de condiciones de orden superior
# si se busca mayor regularidad.

# %% [markdown]
# ## Interpretación geométrica o física
#
# La frontera actúa como un espejo. La reflexión impar cambia el signo del
# pulso y fuerza \(u(0,t)=0\); la reflexión par conserva el signo y fuerza
# \(u_x(0,t)=0\).

# %% [markdown]
# ## Ejemplo guiado
#
# Para Dirichlet, \(f(x)=xe^{-x}\), \(g=0\), se define
# \(\tilde f(x)=xe^{-|x|}\), que es impar, y se usa d'Alembert con \(\tilde f\).

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 02.02.1
#
# Resuelve el problema de Dirichlet homogéneo con \(f(x)=xe^{-x}\), \(g=0\), y determina cuándo el pulso reflejado aparece en \(x=1\).
#
# ### Ejercicio normal 02.02.2
#
# Deriva la fórmula de Neumann homogénea por extensión par y comprueba \(u_x(0,t)=0\).

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
