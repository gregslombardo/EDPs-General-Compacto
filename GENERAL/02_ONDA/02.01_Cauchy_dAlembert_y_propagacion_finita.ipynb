# %% [markdown]
# # 02.01 — Problema de Cauchy, d'Alembert y propagación finita
#
# **Prioridad para el General:** ALTA
# **Patrón histórico:** d'Alembert y soporte fueron el centro del General 2026-1.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# Para \(u_{tt}-c^2u_{xx}=0\), \(u(x,0)=f(x)\),
# \(u_t(x,0)=g(x)\),
# \[
# u(x,t)=\frac{f(x-ct)+f(x+ct)}2+
# \frac1{2c}\int_{x-ct}^{x+ct}g(y)\,dy.
# \]
# El valor en \((x,t)\) sólo depende del intervalo \([x-ct,x+ct]\), la base de
# su cono pasado.

# %% [markdown]
# ## Interpretación geométrica o física
#
# La perturbación viaja a velocidad finita \(c\). El dato de desplazamiento
# se separa en ondas derecha e izquierda y el dato de velocidad llena el
# interior del cono.

# %% [markdown]
# ## Visualización
#
# <video controls preload="metadata" style="max-width: 100%; height: auto;">
#   <source src="../../ONDA/animaciones/02_01_dAlembert_2K_120fps.mp4" type="video/mp4">
# </video>
#
# > Si el reproductor no carga en GitHub, abre el notebook localmente; la ruta es relativa al repositorio.

# %% [markdown]
# ## Ejemplo guiado
#
# Si \(g=0\) y \(f\) está soportada en \([-1,1]\), entonces
# el soporte de \(u(\cdot,t)\) está contenido en
# \([-1-ct,1+ct]\).

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 02.01.1
#
# Usa d'Alembert para \(f(x)=e^{-x^2}\), \(g=0\), y verifica ambos datos iniciales.
#
# ### Ejercicio normal 02.01.2
#
# Si \(f,g\) se anulan en \([x_0-ct_0,x_0+ct_0]\), demuestra que \(u(x_0,t_0)=0\).
#
# ### Problema tipo General 02.01.G
#
# Sean \(f,g\) suaves y soportadas en \([-a,a]\).
# Determine el soporte máximo de \(u(\cdot,t)\), demuestre la afirmación desde
# d'Alembert y construya datos no triviales para los que la inclusión sea
# estricta en un tiempo dado.

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
