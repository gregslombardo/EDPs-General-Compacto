# %% [markdown]
# # 04.02 — Principio débil del máximo, comparación y unicidad
#
# **Prioridad para el General:** ALTA
# **Patrón histórico:** Comparación y términos de orden cero fueron evaluados en 2026-1.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# En \(\Omega_T=\Omega\times(0,T]\), la frontera parabólica es
# \[
# \Gamma_T=(\overline\Omega\times\{0\})\cup
# (\partial\Omega\times[0,T]).
# \]
# Si \(u_t-\Delta u\le0\), entonces
# \(\max_{\overline{\Omega_T}}u=\max_{\Gamma_T}u\). Aplicar el principio a
# \(u-v\) da comparación, estabilidad en norma supremo y unicidad.

# %% [markdown]
# ## Interpretación geométrica o física
#
# El tiempo tiene orientación: la frontera relevante incluye el instante
# inicial y la pared lateral, no la tapa \(t=T\). El máximo sólo puede entrar
# desde el pasado o la pared.

# %% [markdown]
# ## Ejemplo guiado
#
# Si \(u,v\) tienen la misma fuente, entonces
# \(w=u-v\) satisface la ecuación homogénea y
# \(\|w\|_{\infty,\Omega_T}\le\|w\|_{\infty,\Gamma_T}\).

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 04.02.1
#
# Escribe \(\Gamma_T\) para \(\Omega=B_1(0)\) y explica por qué la tapa superior no se incluye.
#
# ### Ejercicio normal 04.02.2
#
# Demuestra la estabilidad supremo para dos soluciones con igual fuente y datos de frontera distintos.

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
