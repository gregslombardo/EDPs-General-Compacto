# %% [markdown]
# # 04.04 — Problema no homogéneo y principio de Duhamel
#
# **Prioridad para el General:** ALTA
# **Patrón histórico:** La fuente y la frontera variable aparecieron en 2025-2.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# Para
# \[
# u_t-\Delta u=F,\qquad u(\cdot,0)=g
# \]
# en todo el espacio,
# \[
# u(x,t)=\psi_t*g(x)+\int_0^t\psi_{t-s}*F(\cdot,s)(x)\,ds.
# \]
# La derivación usa el semigrupo del calor y requiere justificar el límite en
# \(s=t\). En dominios con frontera se combina con levantamientos o con el
# semigrupo del operador con condiciones de frontera.

# %% [markdown]
# ## Interpretación geométrica o física
#
# La fuente deposita calor continuamente. Cada depósito hecho en tiempo
# \(s\) evoluciona durante \(t-s\), no durante \(t\).

# %% [markdown]
# ## Ejemplo guiado
#
# Si \(F(x,t)=e^{-t}h(x)\), la respuesta forzada es
# \(\int_0^te^{-s}\psi_{t-s}*h\,ds\).

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 04.04.1
#
# Verifica formalmente que la fórmula de Duhamel satisface la ecuación y el dato inicial.
#
# ### Ejercicio normal 04.04.2
#
# Prueba una cota supremo de la respuesta forzada en términos de \(\int_0^t\|F(\cdot,s)\|_\infty ds\).

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
