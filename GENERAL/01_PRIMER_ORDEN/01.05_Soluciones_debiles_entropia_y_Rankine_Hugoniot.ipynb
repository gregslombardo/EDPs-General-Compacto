# %% [markdown]
# # 01.05 — Soluciones débiles, entropía y Rankine-Hugoniot
#
# **Prioridad para el General:** ALTA
# **Patrón histórico:** Los generales 2023-1 y 2025-2 exigen seleccionar la solución entrópica.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# Una solución débil de \(u_t+f(u)_x=0\) satisface
# \[
# \iint (u\varphi_t+f(u)\varphi_x)\,dxdt+\int u_0\varphi(\cdot,0)\,dx=0.
# \]
# Un salto \(u_L\to u_R\) que viaja con velocidad \(s\) debe cumplir
# \[
# s[u]=[f(u)],\qquad
# s=\frac{f(u_L)-f(u_R)}{u_L-u_R}.
# \]
# Para flujo convexo, un choque entrópico satisface
# \(f'(u_L)>s>f'(u_R)\).

# %% [markdown]
# ## Interpretación geométrica o física
#
# Rankine-Hugoniot es balance de masa a través de un frente móvil. La
# condición de Lax exige que las características entren al choque desde ambos
# lados; un frente del que salen características no es físicamente admisible.

# %% [markdown]
# ## Ejemplo guiado
#
# Para Burgers \(f(u)=u^2/2\), \(u_L=2,\ u_R=0\),
# \(s=(2-0)/(2)=1\). Como \(f'(2)=2>1>0=f'(0)\), el choque es entrópico.

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 01.05.1
#
# Para \(f(u)=u^3/3\), \(u_L=2,\ u_R=1\), calcula \(s\) y verifica la condición de Lax.
#
# ### Ejercicio normal 01.05.2
#
# Demuestra desde la formulación débil que una función constante a cada lado de \(x=st\) exige Rankine-Hugoniot.

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
