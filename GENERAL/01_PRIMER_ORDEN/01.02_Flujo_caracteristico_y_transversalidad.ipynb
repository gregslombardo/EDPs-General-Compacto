# %% [markdown]
# # 01.02 — Flujo característico, jacobiano y transversalidad
#
# **Prioridad para el General:** ALTA
# **Patrón histórico:** La condición de transversalidad fue el núcleo del problema de 2026-1.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# El flujo \(X(s;\xi)\) resuelve \(X'=b(X,s)\). Su jacobiano
# \(J=\det D_\xi X\) satisface la fórmula de Liouville
# \[
# J'(s)=(\nabla\cdot b)(X(s),s)J(s).
# \]
# Para datos prescritos sobre una curva \(\gamma(r)\), la condición local de
# buena posición es que el campo característico no sea tangente:
# \[
# \det\big(\gamma'(r),\,b(\gamma(r))\big)\neq0.
# \]

# %% [markdown]
# ## Interpretación geométrica o física
#
# Transversalidad significa que las características cruzan la curva de datos.
# Si son tangentes, la curva no etiqueta de manera única las trayectorias y
# puede haber incompatibilidad o falta de unicidad.

# %% [markdown]
# ## Visualización
#
# <video controls preload="metadata" style="max-width: 100%; height: auto;">
#   <source src="../../LINEALES/media/videos/LINEALES/1440p120/ProblemaMixtoCompatibilidad.mp4" type="video/mp4">
# </video>
#
# > Si el reproductor no carga en GitHub, abre el notebook localmente; la ruta es relativa al repositorio.

# %% [markdown]
# ## Ejemplo guiado
#
# Para \(b(x,y)=(1,y)\), el sistema \(x'=1,\ y'=y\) da
# \(x=r+s,\ y=y_0e^s\). Por tanto \(J=e^s\), coherente con
# \(\nabla\cdot b=1\).

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 01.02.1
#
# Calcula el flujo y su jacobiano para \(b(x,y)=(x,-y)\). Interpreta la conservación de área.
#
# ### Ejercicio normal 01.02.2
#
# Para \(u_x+xu_y=0\) con datos sobre \(\gamma(r)=(0,r)\), verifica transversalidad y encuentra la solución local.

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
