# %% [markdown]
# # 01.04 — Ecuaciones completamente no lineales y características generalizadas
#
# **Prioridad para el General:** MEDIA
# **Patrón histórico:** Es herramienta del temario; suele evaluarse mediante compatibilidad y geometría, no como bloque aislado.
#
# > Notebook canónico de la ruta compacta. Para estudiar el examen, usa éste en lugar de las versiones extensas o legadas.

# %% [markdown]
# ## Núcleo teórico
#
# Para \(F(x,y,u,p,q)=0\), con \(p=u_x,\ q=u_y\), el sistema de
# Charpit puede escribirse
# \[
# x'=F_p,\quad y'=F_q,\quad
# u'=pF_p+qF_q,
# \]
# \[
# p'=-F_x-pF_u,\qquad q'=-F_y-qF_u.
# \]
# Los datos iniciales deben satisfacer \(F=0\) y ser compatibles con la
# derivada tangencial de \(u\) sobre la curva inicial.

# %% [markdown]
# ## Interpretación geométrica o física
#
# La solución es una superficie; \((p,q)\) describe su plano tangente.
# Las características generalizadas evolucionan simultáneamente el punto, la
# altura y la inclinación.

# %% [markdown]
# ## Ejemplo guiado
#
# Para la eikonal \(p^2+q^2=1\), \(F_p=2p,\ F_q=2q\) y
# \(p,q\) son constantes sobre cada característica. La proyección al plano es
# una recta.

# %% [markdown]
# ## Práctica esencial
#
# La cuenta es literal: dos ejercicios normales. Sólo los temas marcados llevan un tercero de nivel General.
#
# ### Ejercicio normal 01.04.1
#
# Escribe el sistema de Charpit para \(u_xu_y=u\) y señala qué variables permanecen constantes si las hay.
#
# ### Ejercicio normal 01.04.2
#
# Para \(u_x^2+u_y^2=1\) con \(u(x,0)=x\), verifica compatibilidad y describe las características iniciales.

# %% [markdown]
# ## Autochequeo
#
# - ¿Puedo enunciar las hipótesis antes de usar la fórmula?
# - ¿Puedo dibujar o explicar la geometría relevante?
# - ¿Puedo verificar ecuación, datos y frontera al terminar?
# - ¿Sé por qué este método es preferible a los otros del bloque?
